# %%
import pandas as pd

# %%
population= pd.read_csv("World-population-by-countries-dataset.csv",index_col=False)

# %%
population
# Out:
#                     Country Name Country Code         1960         1961  \
# 0                          Aruba          ABW      54208.0      55434.0
# 1    Africa Eastern and Southern          AFE  130836765.0  134159786.0
# 2                    Afghanistan          AFG    8996967.0    9169406.0
# 3     Africa Western and Central          AFW   96396419.0   98407221.0
# 4                         Angola          AGO    5454938.0    5531451.0
# ..                           ...          ...          ...          ...
# 261                       Kosovo          XKX     947000.0     966000.0
# 262                  Yemen, Rep.          YEM    5315351.0    5393034.0
# 263                 South Africa          ZAF   17099836.0   17524533.0
# 264                       Zambia          ZMB    3070780.0    3164330.0
# 265                     Zimbabwe          ZWE    3776679.0    3905038.0
#
#             1962         1963         1964         1965         1966  \
# ...

# %%
year2022= population['2021']

# %%
year2022
# Out:
# 0         107195.0
# 1      694665117.0
# 2       39835428.0
# 3      470898870.0
# 4       33933611.0
#           ...
# 261      1806279.0
# 262     30490639.0
# 263     60041996.0
# 264     18920657.0
# 265     15092171.0
# Name: 2021, Length: 266, dtype: float64

# %%
year2022ordered= population[['2021','1960']]

# %%
year2022ordered
# Out:
#             2021         1960
# 0       107195.0      54208.0
# 1    694665117.0  130836765.0
# 2     39835428.0    8996967.0
# 3    470898870.0   96396419.0
# 4     33933611.0    5454938.0
# ..           ...          ...
# 261    1806279.0     947000.0
# 262   30490639.0    5315351.0
# 263   60041996.0   17099836.0
# 264   18920657.0    3070780.0
# 265   15092171.0    3776679.0
#
# [266 rows x 2 columns]

# %%
year2022ordered.plot()
# Out:
# <AxesSubplot:>

# %%
population.set_index('Country Name', inplace=True)

# %%
population
# Out:
#                             Country Code         1960         1961  \
# Country Name
# Aruba                                ABW      54208.0      55434.0
# Africa Eastern and Southern          AFE  130836765.0  134159786.0
# Afghanistan                          AFG    8996967.0    9169406.0
# Africa Western and Central           AFW   96396419.0   98407221.0
# Angola                               AGO    5454938.0    5531451.0
# ...                                  ...          ...          ...
# Kosovo                               XKX     947000.0     966000.0
# Yemen, Rep.                          YEM    5315351.0    5393034.0
# South Africa                         ZAF   17099836.0   17524533.0
# Zambia                               ZMB    3070780.0    3164330.0
# Zimbabwe                             ZWE    3776679.0    3905038.0
#
#                                     1962         1963         1964  \
# Country Name
# ...

# %%
year2022= population['2021']

# %%
year2022
# Out:
# Country Name
# Aruba                             107195.0
# Africa Eastern and Southern    694665117.0
# Afghanistan                     39835428.0
# Africa Western and Central     470898870.0
# Angola                          33933611.0
#                                   ...
# Kosovo                           1806279.0
# Yemen, Rep.                     30490639.0
# South Africa                    60041996.0
# Zambia                          18920657.0
# Zimbabwe                        15092171.0
# Name: 2021, Length: 266, dtype: float64

# %%
year2022ordered= population[['2021','1960']]

# %%
year2022ordered
# Out:
#                                     2021         1960
# Country Name
# Aruba                           107195.0      54208.0
# Africa Eastern and Southern  694665117.0  130836765.0
# Afghanistan                   39835428.0    8996967.0
# Africa Western and Central   470898870.0   96396419.0
# Angola                        33933611.0    5454938.0
# ...                                  ...          ...
# Kosovo                         1806279.0     947000.0
# Yemen, Rep.                   30490639.0    5315351.0
# South Africa                  60041996.0   17099836.0
# Zambia                        18920657.0    3070780.0
# Zimbabwe                      15092171.0    3776679.0
#
# [266 rows x 2 columns]

# %%
smallest10=year2022ordered.nsmallest(7,'2021')

# %%
smallest10
# Out:
#                            2021     1960
# Country Name
# Nauru                   10873.0   4377.0
# Tuvalu                  11925.0   5321.0
# Palau                   18174.0   9769.0
# British Virgin Islands  30423.0   8053.0
# Gibraltar               33691.0  23420.0
# San Marino              34010.0  15440.0
# Liechtenstein           38254.0  16501.0

# %%
smallest10.plot(figsize=(10,5))
# Out:
# <AxesSubplot:xlabel='Country Name'>

# %%
smallest10.plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>
