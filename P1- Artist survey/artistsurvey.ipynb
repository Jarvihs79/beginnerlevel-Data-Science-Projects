# %%
import pandas as pd

# %%
artist = pd.read_csv("Artist Survey Data.csv")

# %%
artist
# Out:
#               timestamp    ID  race_ethnicity    database_language  \
# 0    1/25/2022 14:56:02  1001         Chinese     English, Chinese
# 1     3/17/2022 9:53:29  1002         Chinese   English, Cantonese
# 2    2/16/2022 11:03:44  1003           White              English
# 3    3/16/2022 10:07:22  1005         Chinese              English
# 4    2/22/2022 10:44:37  1008          Latino              Spanish
# ..                  ...   ...             ...                  ...
# 97    2/9/2022 11:56:55  1122           White                  ASL
# 98   3/22/2022 11:28:46  1123           Black              English
# 99    2/7/2022 22:00:36  1125         Chinese  Cantonese, Mandarin
# 100   2/8/2022 14:03:36  1126           Black              English
# 101                 NaN  1068  Middle Eastern                 Dari
#
#     survey_language  survey_completed_for_artist What is your race/ethnicity?  \
# 0           English                            1                        Asian
# ...

# %%
ethnicity= artist["race_ethnicity"].value_counts()

# %%
ethnicity
# Out:
# White                            54
# Black                            19
# Chinese                          10
# Latino                           10
# Filipino                          3
# Middle Eastern                    2
# Japanese/White                    1
# white/Chinese/native american     1
# latino/black                      1
# Vietnamese                        1
# Name: race_ethnicity, dtype: int64

# %%
ethnicity.plot(kind="barh")
# Out:
# <AxesSubplot:>

# %%
readeng = artist["How comfortable are you reading English?"].value_counts()

# %%
readeng
# Out:
# 5    46
# 1    17
# 3    15
# 4    14
# 2    10
# Name: How comfortable are you reading English?, dtype: int64

# %%
readeng.plot(kind="pie", x = "How comfortable are you reading English?")
# Out:
# <AxesSubplot:ylabel='How comfortable are you reading English?'>

# %%
writeeng= artist["How comfortable are you writing English?"].value_counts()

# %%
writeeng
# Out:
# 5    42
# 1    17
# 4    16
# 2    14
# 3    13
# Name: How comfortable are you writing English?, dtype: int64

# %%
writeeng.plot(kind="pie")
# Out:
# <AxesSubplot:ylabel='How comfortable are you writing English?'>
